# %% [markdown]
# ## Data Wrangling I

# %%
import pandas as pd
import numpy as np

# %%
# Loading the dataset
df = pd.read_csv('Datasets/Artists.csv')

# %%
#Describing the dataset
df.describe()
# Out:
#        ConstituentID     BeginDate       EndDate          ULAN
# count   15638.000000  15638.000000  15638.000000  2.931000e+03
# mean    24120.605960   1491.669843    709.111587  5.000744e+08
# std     29489.630661    810.180276    949.239575  8.660346e+04
# min         1.000000      0.000000      0.000000  5.000000e+08
# 25%      4381.250000   1855.250000      0.000000  5.000176e+08
# 50%      9498.500000   1923.000000      0.000000  5.000330e+08
# 75%     35560.250000   1948.000000   1968.000000  5.001146e+08
# max    138567.000000   2017.000000   2024.000000  5.003566e+08

# %%
#Checking for missing values
df.isnull()
# Out:
#        ConstituentID  DisplayName  ArtistBio  Nationality  Gender  BeginDate  \
# 0              False        False      False        False   False      False
# 1              False        False      False        False   False      False
# 2              False        False      False        False   False      False
# 3              False        False      False        False   False      False
# 4              False        False      False        False   False      False
# ...              ...          ...        ...          ...     ...        ...
# 15633          False        False      False        False   False      False
# 15634          False        False      False        False   False      False
# 15635          False        False      False        False   False      False
# 15636          False        False      False        False   False      False
# 15637          False        False      False        False    True      False
#
#        EndDate  Wiki QID   ULAN
# ...

# %%
#Checking for missing values

df['ArtistBio'] = df['ArtistBio'].fillna('Unknown')
df['Nationality'] = df['Nationality'].fillna('Unknown')
df['Gender'] = df['Gender'].fillna('Unknown')
df['Wiki QID'] = df['Wiki QID'].fillna('Unknown')
df['ULAN'] = df['ULAN'].fillna('Unknown')

# %%
df.isnull().sum()
# Out:
# ConstituentID    0
# DisplayName      0
# ArtistBio        0
# Nationality      0
# Gender           0
# BeginDate        0
# EndDate          0
# Wiki QID         0
# ULAN             0
# dtype: int64

# %%
# Checking the data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15638 entries, 0 to 15637
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ConstituentID  15638 non-null  int64
#  1   DisplayName    15638 non-null  object
#  2   ArtistBio      13438 non-null  object
#  3   Nationality    13142 non-null  object
#  4   Gender         12381 non-null  object
#  5   BeginDate      15638 non-null  int64
#  6   EndDate        15638 non-null  int64
#  7   Wiki QID       3247 non-null   object
#  8   ULAN           2931 non-null   float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.1+ MB

# %%
# Checking the data types
df.dtypes
# Out:
# ConstituentID      int64
# DisplayName       object
# ArtistBio         object
# Nationality       object
# Gender            object
# BeginDate          int64
# EndDate            int64
# Wiki QID          object
# ULAN             float64
# dtype: object

# %%
df.describe(include='object')
df.describe(include='number')
# Out:
#        ConstituentID     BeginDate       EndDate          ULAN
# count   15638.000000  15638.000000  15638.000000  2.931000e+03
# mean    24120.605960   1491.669843    709.111587  5.000744e+08
# std     29489.630661    810.180276    949.239575  8.660346e+04
# min         1.000000      0.000000      0.000000  5.000000e+08
# 25%      4381.250000   1855.250000      0.000000  5.000176e+08
# 50%      9498.500000   1923.000000      0.000000  5.000330e+08
# 75%     35560.250000   1948.000000   1968.000000  5.001146e+08
# max    138567.000000   2017.000000   2024.000000  5.003566e+08

# %%
# Checking the whole dataset
df
# Out:
#        ConstituentID             DisplayName                  ArtistBio  \
# 0                  1          Robert Arneson        American, 1930–1992
# 1                  2          Doroteo Arnaiz         Spanish, born 1936
# 2                  3             Bill Arnold        American, born 1941
# 3                  4         Charles Arnoldi        American, born 1946
# 4                  5             Per Arnoldi          Danish, born 1941
# ...              ...                     ...                        ...
# 15633         138522           Erwin Heerich        German, 1922 – 2004
# 15634         138540    Rafael Rivera García  Puerto Rican, 1929 – 2014
# 15635         138541  Rafael López del Campo  Puerto Rican, 1936 – 2009
# 15636         138544            Efrain Lopez  Puerto Rican, 1940 – 1993
# 15637         138567            Jonas Hafner          German, born 1940
#
#         Nationality Gender  BeginDate  EndDate  Wiki QID         ULAN
# ...

# %%
# checking the shape of the dataset 
df.shape
# Out:
# (15638, 9)

# %%
# Checking the first 15 rows of the dataset
df.head(15)
# Out:
#     ConstituentID            DisplayName  \
# 0               1         Robert Arneson
# 1               2         Doroteo Arnaiz
# 2               3            Bill Arnold
# 3               4        Charles Arnoldi
# 4               5            Per Arnoldi
# 5               6          Danilo Aroldi
# 6               7              Bill Aron
# 7               9          David Aronson
# 8              10          Irene Aronson
# 9              11        Jean (Hans) Arp
# 10             12             Jüri Arrak
# 11             13  José Arellano Fischer
# 12             15          Folke Arstrom
# 13             16      Cristobal Arteche
# 14             18                  Artko
#
#                                    ArtistBio Nationality  Gender  BeginDate  \
# 0                        American, 1930–1992    American    male       1930
# 1                         Spanish, born 1936     Spanish    male       1936
# ...

# %%
df.tail(10)
# Out:
#        ConstituentID                         DisplayName  \
# 15628         138440                           Aiko Mogi
# 15629         138441                      Koji Shimosawa
# 15630         138442                        Gengo Matsui
# 15631         138469                        Michael Ross
# 15632         138510  Stephen Prina, American, born 1954
# 15633         138522                       Erwin Heerich
# 15634         138540                Rafael Rivera García
# 15635         138541              Rafael López del Campo
# 15636         138544                        Efrain Lopez
# 15637         138567                        Jonas Hafner
#
#                        ArtistBio   Nationality  Gender  BeginDate  EndDate  \
# 15628                        NaN           NaN  female          0        0
# 15629                        NaN           NaN    male          0        0
# 15630                        NaN           NaN    male          0        0
# ...

# %%
df.dtypes
# Out:
# ConstituentID     int64
# DisplayName      object
# ArtistBio        object
# Nationality      object
# Gender           object
# BeginDate         int64
# EndDate           int64
# Wiki QID         object
# ULAN             object
# dtype: object

# %%
df['ULAN'] = df['ULAN'].replace('Unknown', -1).astype('int64')
df.dtypes
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4656\810919155.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['ULAN'] = df['ULAN'].replace('Unknown', -1).astype('int64')
# ConstituentID     int64
# DisplayName      object
# ArtistBio        object
# Nationality      object
# Gender           object
# BeginDate         int64
# EndDate           int64
# Wiki QID         object
# ULAN              int64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Gender'] = le.fit_transform(df['Gender'])
df
# Out:
#        ConstituentID             DisplayName                  ArtistBio  \
# 0                  1          Robert Arneson        American, 1930–1992
# 1                  2          Doroteo Arnaiz         Spanish, born 1936
# 2                  3             Bill Arnold        American, born 1941
# 3                  4         Charles Arnoldi        American, born 1946
# 4                  5             Per Arnoldi          Danish, born 1941
# ...              ...                     ...                        ...
# 15633         138522           Erwin Heerich        German, 1922 – 2004
# 15634         138540    Rafael Rivera García  Puerto Rican, 1929 – 2014
# 15635         138541  Rafael López del Campo  Puerto Rican, 1936 – 2009
# 15636         138544            Efrain Lopez  Puerto Rican, 1940 – 1993
# 15637         138567            Jonas Hafner          German, born 1940
#
#         Nationality  Gender  BeginDate  EndDate  Wiki QID       ULAN
# ...

# %%
# count = df['Gender'].value_counts()
# count

# %%
dummy = pd.get_dummies(df['Nationality'])
df = pd.concat([df, dummy], axis='columns')

# %%
df
# Out:
#        ConstituentID             DisplayName                  ArtistBio  \
# 0                  1          Robert Arneson        American, 1930–1992
# 1                  2          Doroteo Arnaiz         Spanish, born 1936
# 2                  3             Bill Arnold        American, born 1941
# 3                  4         Charles Arnoldi        American, born 1946
# 4                  5             Per Arnoldi          Danish, born 1941
# ...              ...                     ...                        ...
# 15633         138522           Erwin Heerich        German, 1922 – 2004
# 15634         138540    Rafael Rivera García  Puerto Rican, 1929 – 2014
# 15635         138541  Rafael López del Campo  Puerto Rican, 1936 – 2009
# 15636         138544            Efrain Lopez  Puerto Rican, 1940 – 1993
# 15637         138567            Jonas Hafner          German, born 1940
#
#         Nationality  Gender  BeginDate  EndDate  Wiki QID       ULAN  Afghan  \
# ...
